# %%
import pandas as pd

# %%
#Series:1D data structure
S = pd.Series([3,-5,7,4],index=['a','b','c','d'])
print(S)
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
#DataFrame:2D data structure
data=[['Tagore',100],['Ray',70],['Dutta',50]]
Df=pd.DataFrame(data,columns=['Name','Price'])
print(Df)
# Out:
#      Name  Price
# 0  Tagore    100
# 1     Ray     70
# 2   Dutta     50

# %%
data=[['Tagore',100],['Ray',70],['Dutta',50]]
Df=pd.DataFrame(data)
print(Df)
# Out:
#         0    1
# 0  Tagore  100
# 1     Ray   70
# 2   Dutta   50

# %%
#Read and Write about CSV
data=pd.read_csv('lab2.csv')
data
# Out:
#    Registration No. Name Department
# 0         202100100    A        CSE
# 1         202100101    B        CSE
# 2         202100102    C        CSe
# 3         202100103    D         IT
# 4         202100104    E         IT

# %%
#Read and Write to Excel:
date=pd.read_excel('lab2.xlsx')
date
# Out:
#    Registration No. Name Department
# 0         202100100    A        CSE
# 1         202100101    B        CSE
# 2         202100102    C        CSe
# 3         202100103    D         IT
# 4         202100104    E         IT

# %%
import pandas as pd

data0=data.sort_index()
print(data0)
data1=data.sort_values(by='Name')
print(data1)
print(data.rank())
# Out:
#    Registration No. Name Department
# 0         202100100    A        CSE
# 1         202100101    B        CSE
# 2         202100102    C        CSe
# 3         202100103    D         IT
# 4         202100104    E         IT
#    Registration No. Name Department
# 0         202100100    A        CSE
# 1         202100101    B        CSE
# 2         202100102    C        CSe
# 3         202100103    D         IT
# 4         202100104    E         IT
#    Registration No.  Name  Department
# 0               1.0   1.0         1.5
# 1               2.0   2.0         1.5
# 2               3.0   3.0         3.0
# 3               4.0   4.0         4.5
# 4               5.0   5.0         4.5

# %%
#importing matplotlib module
from matplotlib import pyplot as plt 
#x-axis values
x=[5,2,9,4,7]
#y-axis values
y=[10,5,8,4,2]
#function to plot
plt.plot(x,y)
#function to show the plot 
plt.show()

# %%
#importing matplotlib module
from matplotlib import pyplot as plt 
#x-axis values
x=[5,2,9,4,7]
#y-axis values
y=[10,5,8,4,2]
#function to bar
plt.bar(x,y)
#function to show the bar 
plt.show()

# %%
#importing matplotlib module
from matplotlib import pyplot as plt 
#y-axis values
y=[10,5,8,4,2]
#function to histogram
plt.hist(y)
#function to show the histogram
plt.show()

# %%
#importing matplotlib module
from matplotlib import pyplot as plt 
#x-axis values
x=[5,2,9,4,7]
#y-axis values
y=[10,5,8,4,2]
#function to scatter
plt.scatter(x,y)
#function to show the scatter 
plt.show()

# %%
#importing matplotlib module
from matplotlib import pyplot as plt
import numpy as np

y=np.array([100,77,33,21])
mylabels=['Ram','Modiji','David','Luma']

plt.pie(y,labels=mylabels)
#function to show the plot 
plt.show()

# %%
#python programm to illustrate linear Plotting

month=['Jan','Feb','Mar','Apr','May']
India=[100.6,158.61,305.54,394.96,724.79]
BD=[10.5,25.21,58.65,119.27,274.87]

plt.plot(month,India,color='orange',label='India')
plt.plot(month,BD,color='g',label='Bangladesh')
