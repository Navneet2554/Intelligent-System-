# %%
import pandas as pd
import numpy as np

df=pd.read_csv("C:\\Users\CSE\\Desktop\\202100066\\IS Lab Datasets\\bill_authentication.csv")
df
# Out:
#       Variance  Skewness  Curtosis  Entropy  Class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# Variance    0
# Skewness    0
# Curtosis    0
# Entropy     0
# Class       0
# dtype: int64

# %%
X=df.iloc[:,:-1].values
Y=df.iloc[:,-1].values

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(fill_value=np.nan,strategy='mean')
x=imputer.fit_transform(df)
x
# Out:
# array([[  3.6216 ,   8.6661 ,  -2.8073 ,  -0.44699,   0.     ],
#        [  4.5459 ,   8.1674 ,  -2.4586 ,  -1.4621 ,   0.     ],
#        [  3.866  ,  -2.6383 ,   1.9242 ,   0.10645,   0.     ],
#        ...,
#        [ -3.7503 , -13.4586 ,  17.5932 ,  -2.7771 ,   1.     ],
#        [ -3.5637 ,  -8.3827 ,  12.393  ,  -1.2823 ,   1.     ],
#        [ -2.5419 ,  -0.65804,   2.6842 ,   1.1952 ,   1.     ]])

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
df.iloc[:,1:-1]=ss.fit_transform(df.iloc[:,1:-1])
df
# Out:
#       Variance  Skewness  Curtosis   Entropy  Class
# 0      3.62160  1.149455 -0.975970  0.354561      0
# 1      4.54590  1.064453 -0.895036 -0.128767      0
# 2      3.86600 -0.777352  0.122218  0.618073      0
# 3      3.45660  1.295478 -1.255397 -1.144029      0
# 4      0.32924 -1.087038  0.736730  0.096587      0
# ...        ...       ...       ...       ...    ...
# 1367   0.40614 -0.097693 -0.660962  0.300996      1
# 1368  -1.38870 -1.158984  1.179023  0.730127      1
# 1369  -3.75030 -2.621646  3.759017 -0.754884      1
# 1370  -3.56370 -1.756471  2.552043 -0.043158      1
# 1371  -2.54190 -0.439822  0.298616  1.136464      1
#
# [1372 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(df,test_size=0.25)

# %%
x_train=train_set.iloc[:,0:2].values
y_train=train_set.iloc[:,2].values
x_test=test_set.iloc[:,0:2].values
y_test=test_set.iloc[:,2].values

# %%
from sklearn import svm
model=svm.SVR(kernel='rbf')
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.8081148595119614

# %%
from sklearn import svm
model=svm.SVR(kernel='linear')
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.6685057958511156

# %%
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(df,test_size=0.3)

# %%
x_train=train_set.iloc[:,0:2].values
y_train=train_set.iloc[:,2].values
x_test=test_set.iloc[:,0:2].values
y_test=test_set.iloc[:,2].values

# %%
from sklearn import svm
model=svm.SVR(kernel='rbf')
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.813769155082346

# %%
from sklearn import svm
model=svm.SVR(kernel='linear')
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.6537349055538932

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
yhat = knn.predict(X_test)
accuracy = knn.score(X_test, y_test)
print('The accuracy for KNN model is:', str(accuracy * 100) + '%')
# Out:
# The accuracy for KNN model is: 99.52460152460152%

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
knn = KNeighborsRegressor(n_neighbors=7)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
yhat = knn.predict(X_test)
accuracy = knn.score(X_test, y_test)
print('The accuracy for KNN model is:', str(accuracy * 100) + '%')
# Out:
# The accuracy for KNN model is: 99.2966042966043%
